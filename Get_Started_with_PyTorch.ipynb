# %% [markdown]
# <a href="https://colab.research.google.com/github/LU-ZT/Deep-Learning-with-PyTorch/blob/main/Get_Started_with_PyTorch.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Get Started with PyTorch

# %% [markdown]
# Select preferences and run the command to install PyTorch locally, or get started quickly with one of the supported cloud platforms.
#
# https://pytorch.org/get-started/locally/
#
# ![PyTorch_Select.png](data:image/png;base64,...)
#
# conda install pytorch torchvision torchaudio cudatoolkit=11.1 -c pytorch -c conda-forge

# %% [markdown]
# ## Varification

# %% [markdown]
# To ensure that PyTorch was installed correctly, we can verify the installation by running sample PyTorch code. Here we will construct a randomly initialized tensor.

# %%
# Varification
import torch
x = torch.rand(5, 3)
print(x)
# Out:
# tensor([[0.9933, 0.5513, 0.0706],
#         [0.5879, 0.8954, 0.5801],
#         [0.7349, 0.3206, 0.0651],
#         [0.0969, 0.9644, 0.3821],
#         [0.1411, 0.2375, 0.7376]])

# %% [markdown]
# Additionally, to check if your GPU driver and CUDA is enabled and accessible by PyTorch, run the following commands to return whether or not the CUDA driver is enabled:

# %%
torch.cuda.is_available()
# Out:
# False
